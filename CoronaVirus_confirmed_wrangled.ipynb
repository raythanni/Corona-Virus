# %%
import pandas as pd

# %%
df = pd.read_csv("time_series_covid19_confirmed_global.csv", parse_dates=True
                )

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/16/20  3/17/20  3/18/20  3/19/20  \
# 0        0        0        0  ...       21       22       22       22
# 1        0        0        0  ...       51       55       59       64
# 2        0        0        0  ...       54       60       74       87
# 3        0        0        0  ...        2       39       39       53
# 4        0        0        0  ...        0        0        0        0
#
#    3/20/20  3/21/20  3/22/20  3/23/20  3/24/20  3/25/20
# ...

# %%
del df['Province/State']

# %%
df_melt=df.melt(id_vars=["Country/Region", "Lat", "Long"], 
        var_name="Date")

# %%
df_melt
# Out:
#                Country/Region        Lat        Long     Date  value
# 0                 Afghanistan  33.000000   65.000000  1/22/20      0
# 1                     Albania  41.153300   20.168300  1/22/20      0
# 2                     Algeria  28.033900    1.659600  1/22/20      0
# 3                     Andorra  42.506300    1.521800  1/22/20      0
# 4                      Angola -11.202700   17.873900  1/22/20      0
# 5         Antigua and Barbuda  17.060800  -61.796400  1/22/20      0
# 6                   Argentina -38.416100  -63.616700  1/22/20      0
# 7                     Armenia  40.069100   45.038200  1/22/20      0
# 8                   Australia -35.473500  149.012400  1/22/20      0
# 9                   Australia -33.868800  151.209300  1/22/20      0
# 10                  Australia -12.463400  130.845600  1/22/20      0
# 11                  Australia -28.016700  153.400000  1/22/20      0
# 12                  Australia -34.928500  138.600700  1/22/20      0
# ...

# %%
df_melt2=df_melt.set_index('Country/Region')

# %%
df_melt2.to_csv('confirmed_wrangled.csv')
